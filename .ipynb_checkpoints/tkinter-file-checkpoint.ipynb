# %%
import tkinter
import pandas as pd
import numpy as np
from tkinter import *

file_dir = ""

def read_csv():
    s2fname = filedialog.askopenfilename(title="打开文件", filetypes=[("S2out", "*.csv"), ("All Files", "*")])
    #print(s2fname)
    file_dir = s2fname
    raw_df = pd.read_csv(s2fname, header = None)
    print(raw_df)

root = Tk()
root.title("")

btn1 = Button(root, text="打开文件", font =("宋体",20,'bold'), width=13, height=8, command=read_csv)
btn1.pack(side="left")

root.mainloop()
# Out:
#        0    1      2     3  4
# 0    5.0  2.5   4000  0.05  1
# 1    5.0  2.5   4500  0.05  0
# 2    5.0  2.5   5000  0.05  0
# 3    5.0  2.5   5500  0.05  1
# 4    5.0  2.5   6000  0.05  0
# 5    5.0  2.5   6500  0.05  1
# 6    5.0  2.5   7000  0.05  0
# 7    5.0  2.5   7500  0.05  1
# 8    5.0  2.5   8000  0.05  0
# 9    5.0  2.5   8500  0.05  0
# 10   5.0  2.5   9000  0.05  0
# 11   5.0  2.5   9500  0.05  2
# 12   5.0  2.5  10000  0.05  0
# 13   5.0  2.5  10500  0.05  0
# 14   5.0  2.5  11000  0.05  1
# 15   5.0  2.5  11500  0.05  1
# 16   5.0  2.5  12000  0.05  2
# 17   5.0  2.5  12500  0.05  2
# 18   5.0  2.5  13000  0.05  2
# 19   5.0  2.0   4000  0.05  1
# 20   5.0  2.0   4500  0.05  1
# 21   5.0  2.0   5000  0.05  1
# 22   5.0  2.0   5500  0.05  2
# 23   5.0  2.0   6000  0.05  1
# 24   5.0  2.0   6500  0.05  1
# 25   5.0  2.0   7000  0.05  0
# 26   5.0  2.0   7500  0.05  1
# 27   5.0  2.0   8000  0.05  0
# 28   5.0  2.0   8500  0.05  0
# 29   5.0  2.0   9000  0.05  1
# ..   ...  ...    ...   ... ..
# 350  0.5  9.0   8000  0.05  4
# 351  0.5  9.0   8500  0.05  1
# 352  0.5  9.0   9000  0.05  4
# 353  0.5  9.0   9500  0.05  4
# 354  0.5  9.0  10000  0.05  4
# 355  0.5  9.0  10500  0.05  1
# 356  0.5  9.0  11000  0.05  2
# 357  0.5  9.0  11500  0.05  4
# 358  0.5  9.0  12000  0.05  4
# 359  0.5  9.0  12500  0.05  4
# 360  0.5  9.0  13000  0.05  4
# 361  0.5  6.0   4000  0.05  4
# 362  0.5  6.0   4500  0.05  4
# 363  0.5  6.0   5000  0.05  4
# 364  0.5  6.0   5500  0.05  4
# 365  0.5  6.0   6000  0.05  4
# 366  0.5  6.0   6500  0.05  4
# 367  0.5  6.0   7000  0.05  3
# 368  0.5  6.0   7500  0.05  4
# 369  0.5  6.0   8000  0.05  4
# 370  0.5  6.0   8500  0.05  3
# 371  0.5  6.0   9000  0.05  4
# 372  0.5  6.0   9500  0.05  4
# 373  0.5  6.0  10000  0.05  4
# 374  0.5  6.0  10500  0.05  4
# 375  0.5  6.0  11000  0.05  4
# 376  0.5  6.0  11500  0.05  4
# 377  0.5  6.0  12000  0.05  4
# 378  0.5  6.0  12500  0.05  4
# 379  0.5  6.0  13000  0.05  4
#
# [380 rows x 5 columns]
